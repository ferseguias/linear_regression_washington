# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns = None

# %%
casas = pd.read_excel(r"C:\Users\mituc\Ironhack\Curso\IronLabs\casas_grupo\regression_data.xls")

# %%
casas.head(5)
# Out:
#            id       date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520 2014-10-13         3       1.00         1180      5650     1.0
# 1  6414100192 2014-12-09         3       2.25         2570      7242     2.0
# 2  5631500400 2015-02-25         2       1.00          770     10000     1.0
# 3  2487200875 2014-12-09         4       3.00         1960      5000     1.0
# 4  1954400510 2015-02-18         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15   price
# 0             0    98178  47.5112 -122.257           1340        5650  221900
# 1          1991    98125  47.7210 -122.319           1690        7639  538000
# 2             0    98028  47.7379 -122.233           2720        8062  180000
# 3             0    98136  47.5208 -122.393           1360        5000  604000
# 4             0    98074  47.6168 -122.045           1800        7503  510000

# %%
casas.shape
# Out:
# (21597, 21)

# %%
casas.isnull().sum()
# Out:
# id               0
# date             0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# price            0
# dtype: int64

# %%
casas.duplicated().sum()
# Out:
# 0

# %%
columns = casas.columns
columns
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price'],
#       dtype='object')

# %%
casas.hist(bins = 50, figsize = (20,15))
plt.show()

# %%
casas.corr()
# Out:
#                      id  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# id             1.000000  0.001150   0.005162    -0.012241 -0.131911  0.018608
# bedrooms       0.001150  1.000000   0.514508     0.578212  0.032471  0.177944
# bathrooms      0.005162  0.514508   1.000000     0.755758  0.088373  0.502582
# sqft_living   -0.012241  0.578212   0.755758     1.000000  0.173453  0.353953
# sqft_lot      -0.131911  0.032471   0.088373     0.173453  1.000000 -0.004814
# floors         0.018608  0.177944   0.502582     0.353953 -0.004814  1.000000
# waterfront    -0.002727 -0.006834   0.063744     0.103854  0.021632  0.023755
# view           0.011536  0.080008   0.188386     0.284709  0.074900  0.028814
# condition     -0.023803  0.026496  -0.126479    -0.059445 -0.008830 -0.264075
# grade          0.008188  0.356563   0.665838     0.762779  0.114731  0.458794
# sqft_above    -0.010799  0.479386   0.686668     0.876448  0.184139  0.523989
# sqft_basement -0.005193  0.302808   0.283440     0.435130  0.015418 -0.245715
# yr_built       0.021617  0.155670   0.507173     0.318152  0.052946  0.489193
# yr_renovated  -0.016925  0.018389   0.050544     0.055308  0.007686  0.006427
# zipcode       -0.008211 -0.154092  -0.204786    -0.199802 -0.129586 -0.059541
# lat           -0.001798 -0.009951   0.024280     0.052155 -0.085514  0.049239
# long           0.020672  0.132054   0.224903     0.241214  0.230227  0.125943
# sqft_living15 -0.002701  0.393406   0.569884     0.756402  0.144763  0.280102
# sqft_lot15    -0.138557  0.030690   0.088303     0.184342  0.718204 -0.010722
# price         -0.016772  0.308787   0.525906     0.701917  0.089876  0.256804
#
#                waterfront      view  condition     grade  sqft_above  \
# id              -0.002727  0.011536  -0.023803  0.008188   -0.010799
# bedrooms        -0.006834  0.080008   0.026496  0.356563    0.479386
# bathrooms        0.063744  0.188386  -0.126479  0.665838    0.686668
# sqft_living      0.103854  0.284709  -0.059445  0.762779    0.876448
# sqft_lot         0.021632  0.074900  -0.008830  0.114731    0.184139
# floors           0.023755  0.028814  -0.264075  0.458794    0.523989
# waterfront       1.000000  0.401971   0.016611  0.082888    0.072109
# view             0.401971  1.000000   0.045999  0.251728    0.167609
# condition        0.016611  0.045999   1.000000 -0.146896   -0.158904
# grade            0.082888  0.251728  -0.146896  1.000000    0.756073
# sqft_above       0.072109  0.167609  -0.158904  0.756073    1.000000
# sqft_basement    0.080559  0.277078   0.173849  0.168220   -0.052156
# yr_built        -0.026153 -0.053636  -0.361592  0.447865    0.424037
# yr_renovated     0.092873  0.103951  -0.060788  0.014261    0.023251
# zipcode          0.030272  0.084622   0.002888 -0.185771   -0.261570
# lat             -0.014306  0.005871  -0.015102  0.113575   -0.001199
# long            -0.041904 -0.078107  -0.105877  0.200341    0.344842
# sqft_living15    0.086507  0.280681  -0.093072  0.713867    0.731767
# sqft_lot15       0.030781  0.072904  -0.003126  0.120981    0.195077
# price            0.266398  0.397370   0.036056  0.667951    0.605368
#
#                sqft_basement  yr_built  yr_renovated   zipcode       lat  \
# id                 -0.005193  0.021617     -0.016925 -0.008211 -0.001798
# bedrooms            0.302808  0.155670      0.018389 -0.154092 -0.009951
# bathrooms           0.283440  0.507173      0.050544 -0.204786  0.024280
# sqft_living         0.435130  0.318152      0.055308 -0.199802  0.052155
# sqft_lot            0.015418  0.052946      0.007686 -0.129586 -0.085514
# floors             -0.245715  0.489193      0.006427 -0.059541  0.049239
# waterfront          0.080559 -0.026153      0.092873  0.030272 -0.014306
# view                0.277078 -0.053636      0.103951  0.084622  0.005871
# condition           0.173849 -0.361592     -0.060788  0.002888 -0.015102
# grade               0.168220  0.447865      0.014261 -0.185771  0.113575
# sqft_above         -0.052156  0.424037      0.023251 -0.261570 -0.001199
# sqft_basement       1.000000 -0.133064      0.071233  0.074725  0.110414
# yr_built           -0.133064  1.000000     -0.224907 -0.347210 -0.148370
# yr_renovated        0.071233 -0.224907      1.000000  0.064325  0.029350
# zipcode             0.074725 -0.347210      0.064325  1.000000  0.266742
# lat                 0.110414 -0.148370      0.029350  0.266742  1.000000
# long               -0.144546  0.409993     -0.068321 -0.564259 -0.135371
# sqft_living15       0.200443  0.326377     -0.002695 -0.279299  0.048679
# sqft_lot15          0.017550  0.070777      0.007944 -0.147294 -0.086139
# price               0.323799  0.053953      0.126424 -0.053402  0.306692
#
#                    long  sqft_living15  sqft_lot15     price
# id             0.020672      -0.002701   -0.138557 -0.016772
# bedrooms       0.132054       0.393406    0.030690  0.308787
# bathrooms      0.224903       0.569884    0.088303  0.525906
# sqft_living    0.241214       0.756402    0.184342  0.701917
# sqft_lot       0.230227       0.144763    0.718204  0.089876
# floors         0.125943       0.280102   -0.010722  0.256804
# waterfront    -0.041904       0.086507    0.030781  0.266398
# view          -0.078107       0.280681    0.072904  0.397370
# condition     -0.105877      -0.093072   -0.003126  0.036056
# grade          0.200341       0.713867    0.120981  0.667951
# sqft_above     0.344842       0.731767    0.195077  0.605368
# sqft_basement -0.144546       0.200443    0.017550  0.323799
# yr_built       0.409993       0.326377    0.070777  0.053953
# yr_renovated  -0.068321      -0.002695    0.007944  0.126424
# zipcode       -0.564259      -0.279299   -0.147294 -0.053402
# lat           -0.135371       0.048679   -0.086139  0.306692
# long           1.000000       0.335626    0.255586  0.022036
# sqft_living15  0.335626       1.000000    0.183515  0.585241
# sqft_lot15     0.255586       0.183515    1.000000  0.082845
# price          0.022036       0.585241    0.082845  1.000000

# %%
fig, ax = plt.subplots(figsize = (40,20))
sns.heatmap(casas.corr(), annot = True)
plt.size = (40,40)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10,7))
sns.scatterplot(x='lat', y='long', hue='waterfront', data=casas)
# Out:
# <AxesSubplot:xlabel='lat', ylabel='long'>

# %%
corr_matrix = casas.corr()
corr_matrix["price"].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.701917
# grade            0.667951
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# view             0.397370
# sqft_basement    0.323799
# bedrooms         0.308787
# lat              0.306692
# waterfront       0.266398
# floors           0.256804
# yr_renovated     0.126424
# sqft_lot         0.089876
# sqft_lot15       0.082845
# yr_built         0.053953
# condition        0.036056
# long             0.022036
# id              -0.016772
# zipcode         -0.053402
# Name: price, dtype: float64

# %%
len(casas['zipcode'].unique())
# Out:
# 70

# %%
casas.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# price                     int64
# dtype: object

# %%
casas.describe().T
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# yr_built       21597.0  1.971000e+03  2.937523e+01  1.900000e+03
# yr_renovated   21597.0  8.446479e+01  4.018214e+02  0.000000e+00
# zipcode        21597.0  9.807795e+04  5.351307e+01  9.800100e+04
# lat            21597.0  4.756009e+01  1.385518e-01  4.715590e+01
# long           21597.0 -1.222140e+02  1.407235e-01 -1.225190e+02
# sqft_living15  21597.0  1.986620e+03  6.852305e+02  3.990000e+02
# sqft_lot15     21597.0  1.275828e+04  2.727444e+04  6.510000e+02
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
#
#                         25%           50%           75%           max
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.430000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068500e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747110e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222310e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05
# price          3.220000e+05  4.500000e+05  6.450000e+05  7.700000e+06

# %%
oi= casas[casas['bedrooms']==33]
oi
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 15856  2402100895 2014-06-25        33       1.75         1620      6000
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 15856     1.0           0     0          5      7        1040            580
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 15856      1947             0    98103  47.6878 -122.331           1330
#
#        sqft_lot15   price
# 15856        4700  640000

# %%
casas_no_date = casas.drop(["date"], axis = 1)

# %%
fig, ax = plt.subplots(20, 1, figsize=(20,50))

for i in range(len(casas_no_date.columns)):
    sns.boxplot(x=casas_no_date.columns[i], data=casas_no_date, ax=ax[i])
plt.tight_layout()
plt.show()

# %%
casas_limpio = casas.copy()

# %%
columnas_inutiles = ['date', 'lat','sqft_living', 'sqft_living15', 'sqft_lot', 'sqft_lot15', 'yr_renovated', 'yr_built', 'long', 'id']

# %%
casas_limpio.drop(columnas_inutiles, inplace=True, axis=1)

# %%
casas_limpio.head(1)
# Out:
#    bedrooms  bathrooms  floors  waterfront  view  condition  grade  \
# 0         3        1.0     1.0           0     0          3      7
#
#    sqft_above  sqft_basement  zipcode   price
# 0        1180              0    98178  221900

# %%
casas_limpio['view'].unique()
# Out:
# array([0, 3, 4, 2, 1], dtype=int64)

# %%
casas_limpio[casas_limpio['sqft_basement']==4.820000e+03].count()
# Out:
# bedrooms         1
# bathrooms        1
# floors           1
# waterfront       1
# view             1
# condition        1
# grade            1
# sqft_above       1
# sqft_basement    1
# zipcode          1
# price            1
# dtype: int64

# %%
col = ['floors', 'bathrooms']
for i in col:
    casas_limpio[i]=round(casas_limpio[i],0)

# %%
casas_limpio['bedrooms'].max()
# Out:
# 33

# %%
casas_limpio.drop(casas_limpio[casas_limpio['bedrooms'] == casas_limpio['bedrooms'].max()].index, inplace=True)

# %%
casas_limpio[casas_limpio['condition']==casas_limpio['condition'].min()].shape
# Out:
# (29, 11)

# %%
casas_limpio.drop(casas_limpio[casas_limpio['condition'] == casas_limpio['condition'].min()].index, inplace=True)

# %%
casas_limpio['sqft_basement'].max()
# Out:
# 4130

# %%
casas['sqft_basement'].max()
# Out:
# 4130

# %%
for i in range(1):
    casas_limpio.drop(casas_limpio[casas_limpio['sqft_basement'] == casas_limpio['sqft_basement'].max()].index, inplace=True)

# %%
casas['bathrooms'].min()
# Out:
# 0.5

# %%
casas_limpio['bathrooms'].min()
# Out:
# 0.0

# %%
casas_limpio[casas_limpio['bathrooms']==casas_limpio['bathrooms'].min()].count()
# Out:
# bedrooms         4
# bathrooms        4
# floors           4
# waterfront       4
# view             4
# condition        4
# grade            4
# sqft_above       4
# sqft_basement    4
# zipcode          4
# price            4
# dtype: int64

# %%
casas_limpio.drop(casas_limpio[casas_limpio['bathrooms'] == 0].index, inplace=True)

# %%
casas_limpio['bat_bed'] = casas_limpio['bathrooms']/casas_limpio['bedrooms']
casas_limpio['sqft_floors'] = casas_limpio['sqft_above']/casas_limpio['floors']

# %%
casas_caras = casas_limpio[casas_limpio['price'] > 650000]

# %%
casas_caras.shape
# Out:
# (5202, 11)

# %%
casas_caras[casas_caras['sqft_basement'] > 0].count()
# Out:
# bedrooms         2572
# bathrooms        2572
# floors           2572
# waterfront       2572
# view             2572
# condition        2572
# grade            2572
# sqft_above       2572
# sqft_basement    2572
# zipcode          2572
# price            2572
# dtype: int64

# %%
casas_limpio[casas_limpio['sqft_basement'] > 0].count()
# Out:
# bedrooms         8480
# bathrooms        8480
# floors           8480
# waterfront       8480
# view             8480
# condition        8480
# grade            8480
# sqft_above       8480
# sqft_basement    8480
# zipcode          8480
# price            8480
# dtype: int64

# %%
casas_limpio[casas_limpio['price'] > 6.450000e+05].count()
# Out:
# bedrooms         5368
# bathrooms        5368
# floors           5368
# waterfront       5368
# view             5368
# condition        5368
# grade            5368
# sqft_above       5368
# sqft_basement    5368
# zipcode          5368
# price            5368
# dtype: int64

# %%
casas_caras.describe().T
# Out:
#                 count           mean            std       min       25%  \
# bedrooms       5202.0       3.830642       0.889144       1.0       3.0
# bathrooms      5202.0       2.611303       0.890037       1.0       2.0
# floors         5202.0       1.762399       0.484389       1.0       1.0
# waterfront     5202.0       0.025183       0.156695       0.0       0.0
# view           5202.0       0.633602       1.203217       0.0       0.0
# condition      5202.0       3.463476       0.687119       2.0       3.0
# grade          5202.0       8.870242       1.223167       5.0       8.0
# sqft_above     5202.0    2553.861207     984.841607     580.0    1770.0
# sqft_basement  5202.0     465.751634     572.235890       0.0       0.0
# zipcode        5202.0   98073.557670      51.312066   98001.0   98033.0
# price          5202.0  997892.712226  478123.563747  650100.0  730000.0
#
#                     50%        75%        max
# bedrooms            4.0        4.0       10.0
# bathrooms           2.0        3.0        8.0
# floors              2.0        2.0        4.0
# waterfront          0.0        0.0        1.0
# view                0.0        0.0        4.0
# condition           3.0        4.0        5.0
# grade               9.0       10.0       13.0
# sqft_above       2460.0     3180.0     9410.0
# sqft_basement       0.0      890.0     4130.0
# zipcode         98074.0    98115.0    98199.0
# price          835000.0  1060000.0  7700000.0

# %%
def outliers(df, col):
    """
    Calculates the interquartile range of a column in a dataframe.
    
    Args:
        df (pandas Data Frame)
        col (string): name of the column
    Returns:
        q1: value of the first quartile
        q2: value of the second quartile
        outlier_iqr: interquartile range
    """
    q1 = np.nanpercentile(df[col], 25)
    q3 = np.nanpercentile(df[col], 75)
    iqr = q3 - q1
    outlier_step = 1.5 * iqr
    return q1, q3, outlier_step

def outliers_df(df, col):
    """
    Separates the outliers of a column in a dataframe.
    
    Args:
        df (pandas Data Frame)
        col (string): name of the column
    Methods:
        Uses the function outliers()
    Returns:
        outliers_data: dataframe with the outliers
    """
    outliers_data = df[(df[col] < outliers(df, col)[0] - outliers(df, col)[2]) | (df[col] > outliers(df, col)[1] + outliers(df, col)[2])]
    return outliers_data

def outliers_index(df, list_col):
    """
    Creates a list and a dictionary with the indexes of the outliers of a list of columns in a dataframe.
    
    Args:
        df (pandas Data Frame)
        list_col (list): list of strings with the names of the columns
    Methods:
        Uses the function outliers_df()
    Returns:
        dicc_index: dictionary with the name of the columns as keys and the indexes of the outliers as values
        outliers: list with the indexes of the outliers
    """
    dicc_index = {}
    for i in list_col:
        if outliers_df(df, i).shape[0] > 0:
            dicc_index[i] = list(outliers_df(df, i).index)
    outliers = list(set([i for sublist in list(dicc_index.values()) for i in sublist]))
    return dicc_index, outliers

# %%
outliers = outliers_index(casas_limpio, casas_limpio.columns)[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5344/4220074357.py in <module>
# ----> 1 outliers = outliers_index(casas_limpio, casas_limpio.columns)[1]
#
# ~\AppData\Local\Temp/ipykernel_5344/1211117563.py in outliers_index(df, list_col)
#      47     dicc_index = {}
#      48     for i in list_col:
# ---> 49         if outliers_df(df, i).shape[0] > 0:
#      50             dicc_index[i] = list(outliers_df(df, i).index)
#      51     outliers = list(set([i for sublist in list(dicc_index.values()) for i in sublist]))
#
# ~\AppData\Local\Temp/ipykernel_5344/1211117563.py in outliers_df(df, col)
#      29         outliers_data: dataframe with the outliers
#      30     """
# ---> 31     outliers_data = df[(df[col] < outliers(df, col)[0] - outliers(df, col)[2]) | (df[col] > outliers(df, col)[1] + outliers(df, col)[2])]
#      32     return outliers_data
#      33
#
# TypeError: 'list' object is not callable

# %%
len(outliers)
# Out:
# 6665

# %%
casas['bat_bed'].min()
# Out:
# 0.14285714285714285
